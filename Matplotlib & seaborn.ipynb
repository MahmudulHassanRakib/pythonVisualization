# %% [markdown]
# ## Matplotlib Tutorial
#
# Matplotlib is a plotting library for the python programming language and its numerical mathematics extension Numpy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter,wxPython,Qt or GTK+.
#
# Some of the major pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom Labels and texts
# - Great control of every element in a figure
# - High-Quality output in many formarts
# - Very customizable in general

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
## Simple Examples

x=np.arange(0,10)   ## 
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
## plotting using matplotlib

##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Graph in 2D')
plt.savefig('test matplot.png')   ## save file

# %%
y= x*x

# %%
## plt plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %%
## Creating Subplot

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x = np.arange(1,11)
y = 3* x + 5
plt.title('Matplot demo')
plt.xlabel('x axis caption')
plt.ylabel('y label caption')
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
## compute the x and y coordinates for points on a sine curve

x= np.arange(0, 4*np.pi,0.1)
y = np.sin(x)
plt.title('Sine wave plot')

## plot the points using matplotlib
plt.plot(x,y)
plt.show()

# %%
# subplot()
# compute the x and y coordinates for points on sine and cosine curves

x= np.arange(0,5* np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

## set up a subplot grid that has height 2( means has 2 rows) and width 1( means 1 columns)
# and set the first such subplot as active
plt.subplot(2,1,1)

# make the first plot
plt.plot(x,y_sin,'r--')
plt.title('sine')

# set the second subplot as active and make the second plot
plt.subplot(2,1,2)
plt.plot(x,y_cos,'g--')
plt.title('cosine')

# Show the figure
plt.show()

# %%
## Bar plot

x= [2,8,10]
y= [11,16,9]

x2= [3,6,9]
y2= [6,15,7]
plt.bar(x,y)
plt.bar(x2,y2, color='g')     ## color attribute must, but you can write only 'g' in scatter plot
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('x axis')

plt.show()

# %% [markdown]
# ## Histogram

# %%
a= np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title('histogram')
plt.show()

# %%
a= np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,bins=20)   ## indicate the groups
plt.title('histogram')
plt.show()

# %%
# Sample data
data = np.random.randn(1000)  # 1000 points from a normal distribution

# Plot histogram with 20 bins
plt.hist(data, bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram with 20 Bins')

# Show the plot
plt.show()

# %% [markdown]
# ## Box ploting using matplotlib

# %%
data= [np.random.normal(0,std,100) for std in range(1,4)]   # here 0= mean,

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=False)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightblue', color='black'),
            medianprops=dict(color='red'))

plt.title('Custom Box Plot')
plt.xlabel('Values')
plt.show()

# %%
# Generate more sample data
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(90, 20, 200)
data3 = np.random.normal(110, 5, 200)

# Create multiple box plots
plt.boxplot([data1, data2, data3], labels=['Group 1', 'Group 2', 'Group 3'])

# Add labels and title
plt.title('Multiple Box Plots')
plt.ylabel('Values')

# Display the plot
plt.show()

# %% [markdown]
# ## Pie chart

# %%
## data to plot
labels = ['python','c++','Ruby','Java']
sizes= [215,130,245,210]
color= ['gold','yellowgreen','lightcoral','lightskyblue']
explode= [0.4,0,0,0]  # explode first slice

# plot
plt.pie(sizes,explode=explode,labels=labels,colors=color,autopct='%1.1f%%',shadow=False)

plt.axis('equal')
plt.show()

# %% [markdown]
# ## seaborn Tutorial

# %% [markdown]
# ## distribution plots

# %% [markdown]
# - distplot
# - joinplot
# - pairplot
#
# practise problem on IRIS Dataset

# %%
import seaborn as sns

# %%
df= sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Correlation with heatmap
#
# A correlation heatmap uses colored cells, typically in a monochromatic scale, to show a 2D correlation matrix(table) between two discrete dimension or event types. It is very important in feature selection.

# %%
df.corr()
# Out:
# C:\Users\mhamu\AppData\Local\Temp\ipykernel_12144\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\mhamu\AppData\Local\Temp\ipykernel_12144\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# ## joinplot
#
# A joinplot allows to study the relationship between 2 numeric variables. The central chart display their correlation. It is a scatterplot, a hexbin plot,a 2D histogram or a 2D density plot

# %% [markdown]
# ## univarient analysis

# %%
sns.jointplot(x="tip",y='total_bill',data=df)

# %%
sns.jointplot(x="tip",y='total_bill',data=df,kind='reg')

# %%
sns.jointplot(x="tip",y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x="tip",y='total_bill',data=df,kind='kde')

# %% [markdown]
# ## Distplot

# %%
sns.displot(df['total_bill'])  #Also can use histplot that also give the same result

# %%
sns.displot(df['total_bill'],kde=True, bins=30)   ##Kde indicates the kernel density estimator & Bins indicates the hopw many partitions

# %% [markdown]
# ## pairplot
#
# A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.rugplot(df['total_bill'])   ## it is kind of distplot
# Out:
# <Axes: xlabel='total_bill'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',data=df,estimator=sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='smoker',y='total_bill',data=df,estimator=sum)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='smoker')      ## almost provide same things as boxplot
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='smoker',split='true')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Stripplot

# %%
sns.stripplot(x='day', y='total_bill', data=df,)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=df, hue='sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## SwarmPlot

# %% [markdown]
# Combine a stripplot and a violinplot to get a swarmplot. It shows the distribution of a numerical variable for different categories. It is a categorical equivalent of a kdeplot.

# %%
sns.swarmplot(x='day', y='total_bill', data=df)   ## LIke violinplot
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# similarity between the two catagorizations
sns.violinplot(x='day', y='total_bill', data=df)
sns.swarmplot(x='day', y='total_bill', data=df, color='black')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# There is a plot called factorplot which is a general plot that can be used to draw categorical plots. It can be used to draw barplots, countplots, boxplots, violinplots, swarmplots, etc. It is a general plot that can be used to draw categorical plots.

# %%
sns.catplot(x='day', y='total_bill', data=df, kind='bar')

# %%
sns.catplot(x='day', y='total_bill', data=df, kind='violin')

# %% [markdown]
# ## Matirx Plot

# %%
# setting up the datasets for the Matrix plot
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ## Heatmap
#
# A heatmap is a 2D representation of a matrix where the individual values are represented as colors.It is used to visualization the correlation between numerical variables.
#
# For example we can use the correlation between the numerical variables in the tips dataset to get a heatmap.By correlation i mean the ratio of change between two variables. For example if variable A increase 10% and variable B increase by 20% then the correlation between A and B is 2.

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tc = tips.corr(numeric_only=True)

# %%
sns.heatmap(tc)
# Out:
# <Axes: >

# %%
#we can change the color of the heatmap
sns.heatmap(tc, annot=True, cmap='coolwarm') #cmap is the color mapping argument and annot is the annotation argument where the numbers are displayed
# Out:
# <Axes: >

# %%
flights.pivot_table(index='month',columns='year', values='passengers')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
fp = flights.pivot_table(index='month',columns='year', values='passengers')

# %%
sns.heatmap(fp)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp, cmap='plasma', linewidth=0.5, linecolor='white') ## linewidth is the width of the lines and linecolor is the color of the lines
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Clustermap

# %%
sns.clustermap(fp,cmap='plasma')

# %% [markdown]
# ## Grids

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df)

# %%
sns.PairGrid(df) #this will give us a empty grid

# %%
# so by using pairgrid we have various graphs
g = sns.PairGrid(df)
g.map_diag(sns.histplot) #map diagonal means the diagnoal plots of the pairplot 
g.map_lower(sns.scatterplot) #map lower means the lower plots
g.map_upper(sns.kdeplot) #map upper means the upper plots

# %% [markdown]
# ## Facetgrid
# it gives us a general grid that can be used to draw categorical plots. It can be used to draw barplots, countplots, boxplots, violinplots, swarmplots, etc. It is a general plot that can be used to draw categorical plots.

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.FacetGrid(df, col='time', row='smoker') # this will give us an empty grid

# %%
#we can plot by doing the following
g = sns.FacetGrid(df, col='time', row='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip') # this will give us a scatter plot

# %%
#we can plot by doing the following
g = sns.FacetGrid(df, col='time', row='smoker')
g.map(sns.histplot, 'total_bill',kde=True,) # this will give us a scatter plot

# %% [markdown]
# ## Regression Plot

# %% [markdown]
# ## Lmplot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips) # this will give us a scatter plot with a regression line

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex

# %%
#we can also do some stylling by doing the following
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex', palette='coolwarm', markers=['o','v']) # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and color mapping

# %%
# what seaborn is doing is calling matplotlib.pyplot under the hood to plot the regression line
# this gives us some more customization 
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex', palette='coolwarm', markers=['o','v'], scatter_kws={'s':100}) # kws is the keyword arguments and scatter_kws is the keyword arguments for the scatter plot which is the size of the points

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, col='sex') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, row='sex', col='time') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex

# %%
#we can also do this 
sns.lmplot(x='total_bill',y='tip',data=tips, col='sex', row='time', hue='smoker') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and time

# %% [markdown]
# there is a huge problem with this kind of plots its giving us too much information and its hard to understand what is going on

# %%
# so we can modify the plot
sns.lmplot(data=tips, x='total_bill',y='tip', hue='smoker', col='day') # this will give us a scatter plot with a regression line and catagorization of the total bills by sex and time

# %%
# its giving us 4 plots in one line so we can change the aspect of the plot
sns.lmplot(data=tips, x='total_bill',y='tip', hue='smoker', col='day', aspect=0.6)

# %% [markdown]
# ## Set style

# %%
# sns.set_style("whitegrid") #this will change the style of the plot
# you can also add the following as argument
# sns.set_style("ticks")
# sns.set_style("dark")
sns.set_style("darkgrid")
# sns.set_style("white")
# sns.set_style("whitegrid")
sns.countplot(data=tips, x = "smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# ## Size and Aspect
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',aspect=4,data=tips)

# %% [markdown]
# ## Scale and Context
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale=4)
sns.countplot(x='sex',data=tips,palette='coolwarm')
# Out:
# <Axes: xlabel='sex', ylabel='count'>
